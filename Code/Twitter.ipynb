# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
G = nx.read_edgelist("twitter/100318079.edges",create_using=nx.DiGraph())

# %%
nx.draw(G)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 220
# Number of edges: 8354
# Average in degree:  37.9727
# Average out degree:  37.9727

# %%
G.nodes()

# %%
G = nx.read_edgelist("twitter/103431502.edges",create_using=nx.DiGraph())
print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 91
# Number of edges: 473
# Average in degree:   5.1978
# Average out degree:   5.1978

# %%
nx.draw(G)
